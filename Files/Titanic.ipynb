# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path= pd.read_csv('C:/Users/andre/OneDrive/Escritorio/LenguajesProgramacion/DataAnalyticsPython/Data/titanic.csv')

# %%
path
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
path.plot()

# %%
# %who_ls
# Out:
# ['FirstPlot', 'np', 'path', 'pd', 'plt']

# %%
path.size
# Out:
# 10692

# %%
path.shape
# Out:
# (891, 12)

# %%
path.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
path[['Age']]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
path[['Age']].max()
# Out:
# Age    80.0
# dtype: float64

# %%
path.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
path[['Sex','Age']][path.Age<= 18][path.Sex=='male'].plot()
# Out:
# <ipython-input-44-a02013e7786a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   path[['Sex','Age']][path.Age<= 18][path.Sex=='male'].plot()

# %%
path[['Sex','Age']][path.Age<= 18][path.Sex=='female'].plot()
# Out:
# <ipython-input-45-c82f70009df8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   path[['Sex','Age']][path.Age<= 18][path.Sex=='female'].plot()

# %%
path.set_index('Age')
# Out:
#       PassengerId  Survived  Pclass  \
# Age
# 22.0            1         0       3
# 38.0            2         1       1
# 26.0            3         1       3
# 35.0            4         1       1
# 35.0            5         0       3
# ...           ...       ...     ...
# 27.0          887         0       2
# 19.0          888         1       1
# NaN           889         0       3
# 26.0          890         1       1
# 32.0          891         0       3
#
#                                                    Name     Sex  SibSp  Parch  \
# Age
# 22.0                            Braund, Mr. Owen Harris    male      1      0
# 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 26.0                             Heikkinen, Miss. Laina  female      0      0
# 35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 35.0                           Allen, Mr. William Henry    male      0      0
# ...

# %%
path.reset_index(inplace=True)

path
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...
