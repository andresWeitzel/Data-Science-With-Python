# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path=pd.read_excel("C:/Users/andre/OneDrive/Escritorio/LenguajesProgramacion/DataAnalyticsPython/Data/OfertaEducativa.xls")
path.head()
# Out:
#   DIRECCIÓN DE FORMACIÓN TÉCNICA SUPERIOR (DFTS)       Unnamed: 1  \
# 0                                        CARRERA  ESTABLECIMIENTO
# 1                                 ADMINISTRACIÓN              NaN
# 2                TS en Administración de Seguros       IFTS Nº 01
# 3               TS en Administración de Empresas       IFTS Nº 03
# 4                                            NaN       IFTS Nº 07
#
#                Unnamed: 2   Unnamed: 3                        Unnamed: 4  \
# 0               DIRECCIÓN       BARRIO                           HORARIO
# 1                     NaN          NaN                               NaN
# 2  San Martín 665 4º Piso  San Nicolas    7:45 a 11              18 a 22
# 3  Angel J. Carranza 2045      Palermo                     18:30 a 22:15
# 4              Gaona 1502    Caballito                     18:30 a 21:45
#
#        Unnamed: 5                 Unnamed: 6  \
# 0        TELÉFONO                     CORREO
# ...
